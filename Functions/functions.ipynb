# %%
#create a fn number that checks if n<10.if true print "n is smaller"

# %%
#create a f marks() that checks if 75>=40.if true,Print pass

# %%
#create a fn temperature() that checks if 35>30 if true print "hot".

# %%
#create a fn age() that checks if 18>=18 if true print eligible

# %%
#create a fn number that checks whether 20 is eve or odd

def number(i):
    if i%2==0:
        print("even")
    else:
        print("odd")
number(20)
# Out:
# even

# %%
#Create a fn check() that checks if 10>5 if true,print "10 is greater"

def check():
    if 10>5:
        print("10 is greater")
    else:
        print("10 is smaller")
check()
# Out:
# 10 is greater
