# %%
#Create a fn and pass the details of the students using one parameter

# %%
def marks(*num):
    print(num)
marks(50,60,33,40,55,3,9,2)
# Out:
# (50, 60, 33, 40, 55, 3, 9, 2)

# %%
#10 Create a fn game(name,players=1)and print the game name and number of players

def game(name,player=3):
    print("Name is",name)
    print("Number Of players is:",player)

game("Pubg 2")
# Out:
# Name is Pubg 2
# Number Of players is: 3

# %%
#9.Create a fn Account(name,balance=0)and print the account details

def account(name,balance=0):
    print("Name is:",name)
    print("Balance is ",balance)
account("Arjun")
# Out:
# Name is: Arjun
# Balance is  0

# %%
#8.Create a fn exam(subject,marks=100)and print the subject and total marks

def exam(subject,marks=100):
    print("Subject is:",subject)
    print("Marks is:",marks)
exam("English")
# Out:
# Subject is: English
# Marks is: 100

# %%
#7.Create a fn college(name,course="BCA")and print the details.

def college(name,course="BCA"):
    print("Name is:",name)
    print("course is:",course)
college("Arjun")
# Out:
# Name is: Arjun
# course is: BCA

# %%
#Create a fn login(username,password="12456")and call the fn in two ways


def login(username,password="123456"):
    print("Username is:",username)
    print("Password is:",password)

login("ARJUN HARI")
# Out:
# Username is: ARJUN HARI
# Password is: 123456

# %%
#Create a fn book (title,author="unknown")and print the title and author

def book(title,author="unknown"):
    print("Title:",title)
    print("author:",author)
book("pirades")
# Out:
# Title: pirades
# author: unknown

# %%
#Create a fun movie(name,language="English")and print both values

def movie(name,language="English"):
    print("Name of the movie:",name)
    print("Lanhuage:",language)
movie("Leo")    
movie("EZRA","Malayalam")
# Out:
# Name of the movie: Leo
# Lanhuage: English
# Name of the movie: EZRA
# Lanhuage: Malayalam

# %%
#Create a fn phone(brand,price)and print the brand price

def phone(brand,price):
    print("Brand:",brand)
    print("Price:",price)
phone("Adidas",2200)
# Out:
# Brand: Adidas
# Price: 2200

# %%
#Write a fn calculate(a,b=10)

def calculate(a,b=10):
    print(a+b)
calculate(10)
# Out:
# 20

# %%
#Write a fn employee(Name,department="IT")Call it for:"Rahul","Anu","HR"

def employee(name,department="IT"):
    print("Name:",name)
    print("Department:",department)

employee("Rahul")
employee("Anu")
employee("HR")
# Out:
# Name: Rahul
# Department: IT
# Name: Anu
# Department: IT
# Name: HR
# Department: IT

# %%
#Write a fn welcome(name,message="Welcome")and call it: using only name using both arguments

def welcome(name,message="Welcome"):
    print("Name:",name)
    print("message:",message)
welcome("Arjun")
welcome("Arjun","Hi")
# Out:
# Name: Arjun
# message: Welcome
# Name: Arjun
# message: Hi

# %%
#Write a function student (name,age=18) and call it in two different ways.

def student(name,age=18):
    print("Name:",name)
    print("Age:",age)

student("Arjun")
# Out:
# Name: Arjun
# Age: 18

# %%
#Q6.Write a function greet( with name="student") as a default argument call it without passing any argument
def greet(name="Student"):
    print(name)
greet()
# Out:
# Student

# %%
# Q5. Create multiply() that takes two positional arguments and prints their product.
def multiply(a, b):
    print(a * b)

multiply(4, 5)
# Out:
# 20

# %%
# Q4. Create square() that takes one number and prints its square.
def square(n):
    print(n ** 3)

square(5)
# Out:
# 125

# %%
# Q3. Create student() that takes name and age and prints both.
def student(name, age):
    print("Name:", name)
    print("Age:", age)

student("Arjun", 22)
# Out:
# Name: Arjun
# Age: 22

# %%
# Q2. Create add() with two positional arguments and print their sum.
def add(a, b):
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
# Q1. Create greet() with one positional argument name and print the name.
def greet(name):
    print(name)

greet("Arjun")
# Out:
# Arjun

# %%
# write the function called "power", let the default argument to be passed ,pass the value to find resultant of this expression 

def power(a, b=2):
    return a**b
power(8)
# Out:
# 64

# %%
def add(a,b,c=5):
    d=a+b+c
    print(d)
add(40,20,10)  #here value is passing so c=5 not work
# Out:
# 70

# %%
def add(a,b,c=5):
    d=a+b+c
    print(d)
add(4,2)
# Out:
# 11

# %%
#Create a fn called sum pass 3 values but receive only two

def sum(a,b,c):
    d=a+b+c
    print(d)

sum(10,20,40)
# Out:
# 70

# %%
#Create a class called details pass the name of the student,mark and grade

def details(name,mark,grade):
    print("Name-",name)
    print("Mark-",mark)
    print("Grade-",grade)
details("Arjun",88,"B+")
# Out:
# Name- Arjun
# Mark- 88
# Grade- B+

# %%
#create the functtion name sum pass 2 arguments and execute it

def sum(a,b):
    c=a+b
    print(c)
sum(10,20)
# Out:
# 30

# %%
def numbers(list):
    print("Length:", len(list))
    print("Sum:", sum(list))
    print("Maximum:", max(list))
    print("Minimum:", min(list))
list = []

n = int(input("Enter the number of values: "))

for i in range(n):
    value = int(input("Enter value: "))
    list.append(value)

numbers(list)
# Out:
# Length: 4
# Sum: 70
# Maximum: 23
# Minimum: 12

# %%
#Create a list within func and pass the values to find len(),sum(),max(), min() from the list

def numbers():
    list = [10, 20, 30, 40, 50]

    print("Length:", len(list))
    print("Sum:", sum(list))
    print("Maximum:", max(list))
    print("Minimum:", min(list))

numbers()
# Out:
# Length: 5
# Sum: 150
# Maximum: 50
# Minimum: 10

# %%
#Get a value from the user and append it

list = []
value = int(input("Enter a number: "))
list.append(value)
print(list)
# Out:
# [22]

# %%
#Create a list within func and pass the values to append it to the list

def func(a):
    lst=[10,20,30,40]
    lst.append(a)
    print(lst)
func(50)
# Out:
# [10, 20, 30, 40, 50]

# %%
#Create a list within func and pass the values to append it to the list

def values(a, b, c):
    list = []
    list.append(a)
    list.append(b)
    list.append(c)
    print(list)

values(10,20,30)
# Out:
# [10, 20, 30]

# %%
#Create a func called d1()and print numbers 1-5 using while-loop

def d1():
    i = 1
    while i <= 5:
        print(i)
        i += 1
d1()
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Create a func called maths() pass the values and perform add,sub,mul,div,mod,power

def maths(a, b):
    print("Addition:",a + b)
    print("Subtraction:",a - b)
    print("Multiplication:",a * b)
    print("Division:",a / b)
    print("Modulus:",a % b)
    print("Power:",a ** b)
maths(10, 3)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Modulus: 1
# Power: 1000

# %%
#create a fn print hello multiple times using different fn calling.

def fun():
    print("Hello World")
fun()
fun()
fun()
fun()  
fun()
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
#8.Create a fn check that checks whether 25 is divisible bt 5.if true,print "Divisible"

def check():
    if 25%5==0:
        print("Divisble")
    else:
        print("Not Divisible")
check()
# Out:
# Divisble

# %%
#7.Create a function check() that checks whther 100==100.if true print both are equal

def check():
    if 100==100:
        print("Both are equal")
    else:
        print("Not equal")
check()
# Out:
# Both are equal

# %%
#6.create a fn number that checks if n<10.if true print "n is smaller"

def number(n):
    if n<10:
        print("n is smaller")
    else:
        print("n is greater")
number(7)
# Out:
# n is smaller

# %%
#5.create a f marks() that checks if 75>=40.if true,Print pass

def marks():
    if 75>=40:
        print("Pass")
    else:
        print("Fail")    

marks()
# Out:
# Pass

# %%
#4.create a fn temperature() that checks if 35>30 if true print "hot".

def temperature():
    if 35>30:
        print("Hot")
    else:
        print("Cold")
temperature()
# Out:
# Hot

# %%
#3.create a fn age() that checks if 18>=18 if true print eligible
def age():
    if 18>=18:
        print("Eligible")
    else:
        print("Not Eligible")
age()
# Out:
# Eligible

# %%
#2.create a fn number that checks whether 20 is eve or odd

def number(i):
    if i%2==0:
        print("even")
    else:
        print("odd")
number(20)
# Out:
# even

# %%
#1.Create a fn check() that checks if 10>5 if true,print "10 is greater"

def check():
    if 10>5:
        print("10 is greater")
    else:
        print("10 is smaller")
check()
# Out:
# 10 is greater
