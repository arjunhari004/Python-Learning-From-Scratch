# %%
#1
def phone(brand,price):
    print(brand,price,sep=":")
phone("Vivo",20000)
# Out:
# Vivo:20000

# %%
#2
def movie(name,language="English"):
    print(name,language,sep=",")

movie('Avengers')
# Out:
# Avengers,English

# %%
#3
def movie(title,author):
    print(title,author,sep=",")

movie("Harry Potter","J K Rowling")
# Out:
# Harry Potter,J K Rowling

# %%
#4
def login(username, password="12345"):
    print("Username:", username)
    print("Password:", password)

login("Anandan")
login("Anandan", "mypassword")
# Out:
# Username: Anandan
# Password: 12345
# Username: Anandan
# Password: mypassword

# %%
#5
def college(name, course="BCA"):
    print("College Name:", name)
    print("Course:", course)

college("St. Josephs")
college("St. Josephs", "MCA")
# Out:
# College Name: St. Josephs
# Course: BCA
# College Name: St. Josephs
# Course: MCA

# %%
#6
def travel(place, days=2):
    print("Travel Place:", place)
    print("Number of Days:", days)

travel("Goa")
travel("Goa", 5)
# Out:
# Travel Place: Goa
# Number of Days: 2
# Travel Place: Goa
# Number of Days: 5

# %%
#7
def order(item, quantity=1):
    print("Item:", item)
    print("Quantity:", quantity)

order("Pizza")
order("Pizza", 3)
# Out:
# Item: Pizza
# Quantity: 1
# Item: Pizza
# Quantity: 3

# %%
#8
def exam(subject, marks=100):
    print("Subject:", subject)
    print("Total Marks:", marks)

exam("Maths")
exam("Maths", 80)
# Out:
# Subject: Maths
# Total Marks: 100
# Subject: Maths
# Total Marks: 80

# %%
#9
def account(name, balance=0):
    print("Account Holder:", name)
    print("Balance:", balance)

account("Anandan")
account("Anandan", 5000)
# Out:
# Account Holder: Anandan
# Balance: 0
# Account Holder: Anandan
# Balance: 5000

# %%
#10
def game(name, players=1):
    print("Game Name:", name)
    print("Number of Players:", players)

game("Chess")
game("Chess", 2)
# Out:
# Game Name: Chess
# Number of Players: 1
# Game Name: Chess
# Number of Players: 2

# %%
#11
def display(name, age=20):
    print(name, age)

display("Anandan")
display("Anandan", 25)
display("Rahul", 30)
# Out:
# Anandan 20
# Anandan 25
# Rahul 30

# %%
#12
def calculate(a, b=5):
    print(a + b)

calculate(10)
calculate(20)
calculate(7, 3)
# Out:
# 15
# 25
# 10

# %%
#13
def discount(price, discount=10):
    print(price, discount)

discount(500)
discount(500, 20)
# Out:
# 500 10
# 500 20

# %%
#14
def employee(name, salary=20000):
    print(name, salary)

employee("Anandan")
employee("Rahul", 25000)
employee("Meera", 30000)
# Out:
# Anandan 20000
# Rahul 25000
# Meera 30000

# %%
#15
def welcome(name="Guest"):
    print("Welcome,", name)

welcome()
welcome("Anandan")
welcome("Rahul")
welcome("Meera")
welcome("Guest User")
# Out:
# Welcome, Guest
# Welcome, Anandan
# Welcome, Rahul
# Welcome, Meera
# Welcome, Guest User

# %%
#16
def add(a, b=10):
    print(a + b)

add(5)
add(20)
add(7, 3)
add(15, 25)
add(100)
# Out:
# 15
# 30
# 10
# 40
# 110

# %%
#17
def student(name, course="Python", duration=3):
    print(name, course, duration)

student("Anandan")
student("Rahul", "Java")
student("Meera", "C++", 4)
student("Kiran", duration=2)
# Out:
# Anandan Python 3
# Rahul Java 3
# Meera C++ 4
# Kiran Python 2

# %%
#18
def product(name, price, quantity=1):
    total = price * quantity
    print(name, total)

product("Laptop", 50000)
product("Phone", 20000, 2)
# Out:
# Laptop 50000
# Phone 40000

# %%
#19
def ticket(name, price=100):
    print("Name:", name)
    print("Ticket Price:", price)

ticket("Rahul")
ticket("Rahul", 150)
# Out:
# Name: Rahul
# Ticket Price: 100
# Name: Rahul
# Ticket Price: 150

# %%
#20
def salary(name, basic, bonus=5000):
    total = basic + bonus
    print(name, total)

salary("Anandan", 30000)
salary("Rahul", 25000, 7000)
# Out:
# Anandan 35000
# Rahul 32000

# %%
#21
def find_min(*args):
    print(min(args))

find_min(10, 20, 30)
find_min(5, 15, 25, 35)
find_min(100, 50)
# Out:
# 10
# 5
# 50

# %%
#22
def count_numbers(*args):
    print(len(args))

count_numbers(1, 2, 3, 4)
count_numbers(10, 20)
count_numbers(5)
# Out:
# 4
# 2
# 1

# %%
#23
def display_subjects(*args):
    for subject in args:
        print(subject)

display_subjects("Maths", "Science", "English")
display_subjects("History", "Geography")
display_subjects("Biology")
# Out:
# Maths
# Science
# English
# History
# Geography
# Biology

# %%
#24
def calculate_average(*args):
    print(sum(args) / len(args))

calculate_average(10, 20, 30)
calculate_average(5, 15, 25, 35)
calculate_average(100, 200)
# Out:
# 20.0
# 20.0
# 150.0

# %%
#25
def display_items(*args):
    for item in args:
        print(item)

display_items("Shoes", "Bag", "Watch")
display_items("Laptop", "Phone")
display_items("Book")
# Out:
# Shoes
# Bag
# Watch
# Laptop
# Phone
# Book

# %%
#26
def sum_even(*args):
    total = sum(num for num in args if num % 2 == 0)
    print(total)

sum_even(1, 2, 3, 4, 5, 6)
sum_even(10, 15, 20)
sum_even(7, 9, 11)
# Out:
# 12
# 30
# 0

# %%
#27
def sum_odd(*args):
    total = sum(num for num in args if num % 2 != 0)
    print(total)

sum_odd(1, 2, 3, 4, 5, 6)
sum_odd(10, 15, 20)
sum_odd(7, 9, 11)
# Out:
# 9
# 15
# 27

# %%
#28
def display_numbers(*args):
    for num in args:
        print(num)

display_numbers(1, 2, 3, 4)
display_numbers(10, 20)
display_numbers(5)
# Out:
# 1
# 2
# 3
# 4
# 10
# 20
# 5

# %%
#29
def find_total_marks(*args):
    print(sum(args))

find_total_marks(80, 90, 70)
find_total_marks(50, 60, 40, 30)
find_total_marks(100, 95)
# Out:
# 240
# 180
# 195

# %%
#30
def count_even(*args):
    count = sum(1 for num in args if num % 2 == 0)
    print(count)

count_even(1, 2, 3, 4, 5, 6)
count_even(10, 15, 20)
count_even(7, 9, 11)
# Out:
# 3
# 2
# 0

# %%
#31
def student_details(**kwargs):
    print(kwargs)

student_details(name="Anandan", age=20, course="Python")
student_details(name="Rahul", age=22)
student_details(name="Meera", age=19, course="Java", duration=3)
# Out:
# {'name': 'Anandan', 'age': 20, 'course': 'Python'}
# {'name': 'Rahul', 'age': 22}
# {'name': 'Meera', 'age': 19, 'course': 'Java', 'duration': 3}

# %%
#32
def employee_details(**kwargs):
    print(kwargs)

employee_details(name="Arjun", salary=30000, dept="HR")
employee_details(name="Kiran", salary=40000)
employee_details(name="Sita", salary=35000, dept="IT")
# Out:
# {'name': 'Arjun', 'salary': 30000, 'dept': 'HR'}
# {'name': 'Kiran', 'salary': 40000}
# {'name': 'Sita', 'salary': 35000, 'dept': 'IT'}

# %%
#33
def product_details(**kwargs):
    print(kwargs)

product_details(name="Laptop", price=50000, brand="Dell")
product_details(name="Phone", price=20000, brand="Samsung")
product_details(name="Shoes", price=3000, brand="Nike")
# Out:
# {'name': 'Laptop', 'price': 50000, 'brand': 'Dell'}
# {'name': 'Phone', 'price': 20000, 'brand': 'Samsung'}
# {'name': 'Shoes', 'price': 3000, 'brand': 'Nike'}

# %%
#34
def display_person(**kwargs):
    print(kwargs)

display_person(name="Anandan", age=20, city="Chennai")
display_person(name="Rahul", age=25)
display_person(name="Meera", age=30, country="India")
# Out:
# {'name': 'Anandan', 'age': 20, 'city': 'Chennai'}
# {'name': 'Rahul', 'age': 25}
# {'name': 'Meera', 'age': 30, 'country': 'India'}

# %%
#35
def college_details(**kwargs):
    print(kwargs)

college_details(name="St. Josephs", course="BCA", location="Bangalore")
college_details(name="Christ College", course="MBA")
college_details(name="IIT", course="CSE", location="Delhi")
# Out:
# {'name': 'St. Josephs', 'course': 'BCA', 'location': 'Bangalore'}
# {'name': 'Christ College', 'course': 'MBA'}
# {'name': 'IIT', 'course': 'CSE', 'location': 'Delhi'}

# %%
#36
def display_marks(**kwargs):
    print(kwargs)

display_marks(Maths=80, Science=90, English=85)
display_marks(History=70, Geography=75)
display_marks(Biology=88, Chemistry=92)
# Out:
# {'Maths': 80, 'Science': 90, 'English': 85}
# {'History': 70, 'Geography': 75}
# {'Biology': 88, 'Chemistry': 92}

# %%
#37
def display_mobile(**kwargs):
    print(kwargs)

display_mobile(brand="Apple", model="iPhone 14", price=80000)
display_mobile(brand="Samsung", model="Galaxy S22", price=60000)
display_mobile(brand="OnePlus", model="10 Pro", price=55000)
# Out:
# {'brand': 'Apple', 'model': 'iPhone 14', 'price': 80000}
# {'brand': 'Samsung', 'model': 'Galaxy S22', 'price': 60000}
# {'brand': 'OnePlus', 'model': '10 Pro', 'price': 55000}

# %%
#38
def display_car(**kwargs):
    print(kwargs)

display_car(brand="Toyota", model="Corolla", year=2020)
display_car(brand="Honda", model="Civic", year=2021)
display_car(brand="Ford", model="Mustang", year=2019)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2020}
# {'brand': 'Honda', 'model': 'Civic', 'year': 2021}
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2019}

# %%
#39
def count_kwargs(**kwargs):
    print(len(kwargs))

count_kwargs(name="Anandan", age=20, course="Python")
count_kwargs(name="Rahul", age=22)
count_kwargs(name="Meera", age=19, course="Java", duration=3)
# Out:
# 3
# 2
# 4

# %%
#40
def display_values(**kwargs):
    for key, value in kwargs.items():
        print(key, value)

display_values(name="Anandan", age=20, course="Python")
display_values(name="Rahul", age=22)
display_values(name="Meera", age=19, course="Java", duration=3)
# Out:
# name Anandan
# age 20
# course Python
# name Rahul
# age 22
# name Meera
# age 19
# course Java
# duration 3
